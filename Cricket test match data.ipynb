# %%
import pandas as pd

# %%
df = pd.read_csv('Cricket Test Match Data.csv')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    *Ave*     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  *99.94*  9800+
# 1      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  *61.87*   2667
# 2     RG Pollock (SA)  1963-1970   23    41   4  2256   274  *60.97*  1707+
# 3     GA Headley (WI)  1930-1954   22    40   4  2190  270*  *60.83*   416+
# 4   H Sutcliffe (ENG)  1924-1935   54    84   9  4555   194  *60.73*  6558+
# ..                ...        ...  ...   ...  ..   ...   ...      ...    ...
# 61   KD Walters (AUS)  1965-1981   74   125  14  5357   250  *48.26*  8662+
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  *48.25*  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  *48.22*  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  *48.21*  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  *48.00*  2110+
#
#        SR  100  50   0    4s  6s
# ...

# %%
df = df.rename(columns = {'Mat':'Matches', 'NO':'Not_Outs' ,'HS':'High_Score', '*Ave*':'Average', 'BF':'Balls_Faced', 'SR':'Batting_Strike_Rate'})

# %%
df.head()
# Out:
#               Player       Span Matches  Inns  Not_Outs  Runs High_Score  \
# 0   DG Bradman (AUS)  1928-1948      52    80        10  6996        334
# 1     AC Voges (AUS)  2015-2016      20    31         7  1485       269*
# 2    RG Pollock (SA)  1963-1970      23    41         4  2256        274
# 3    GA Headley (WI)  1930-1954      22    40         4  2190       270*
# 4  H Sutcliffe (ENG)  1924-1935      54    84         9  4555        194
#
#    Average Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s
# 0  *99.94*       9800+                58.60   29  13  7  626+   6
# 1  *61.87*        2667                55.68    5   4  2   186   5
# 2  *60.97*       1707+                54.48    7  11  1  246+  11
# 3  *60.83*        416+                56.00   10   5  2  104+   1
# 4  *60.73*       6558+                34.59   16  23  2  202+   6

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# High_Score             False
# Average                False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#                   Player       Span Matches  Inns  Not_Outs  Runs High_Score  \
# 8         ED Weekes (WI)  1948-1958      48    81         5  4455        207
# 16       CL Walcott (WI)  1948-1960      44    74         7  3798        220
# 58  Hon.FS Jackson (ENG)  1893-1905      20    33         4  1415       144*
#
#     Average Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s
# 8   *58.61*         NaN                  NaN   15  19  6  258+   2
# 16  *56.68*         NaN                  NaN   15  14  1  107+  11
# 58  *48.79*         NaN                  NaN    5   6  3   51+   0

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].fillna(0)

# %%
df[df['Player']=='Hon.FS Jackson (ENG)']
# Out:
#                   Player       Span Matches  Inns  Not_Outs  Runs High_Score  \
# 58  Hon.FS Jackson (ENG)  1893-1905      20    33         4  1415       144*
#
#     Average Balls_Faced  Batting_Strike_Rate  100  50  0   4s 6s
# 58  *48.79*           0                  0.0    5   6  3  51+  0

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 66, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#                  Player       Span Matches  Inns  Not_Outs   Runs High_Score  \
# 11       GS Sobers (WI)  1954-1974      93   160        21   8032       365*
# 15       JB Hobbs (ENG)  1908-1930      61   102         7   5410        211
# 27     BC Lara (ICC/WI)  1990-2006     131   232         6  11953       400*
# 29  Javed Miandad (PAK)  1976-1993     124   189        21   8832       280*
#
#     Average Balls_Faced  Batting_Strike_Rate  100  50   0    4s   6s
# 11  *57.78*       4063+                53.58   26  30  12  593+  32+
# 15  *56.94*       5363+                46.22   15  28   4  276+    8
# 27  *52.88*       19753                60.51   34  48  17  1559   88
# 29  *52.57*      15164+                45.99   23  43   6  788+   48

# %%
df[df['Player'].isin(['GS Sobers (WI)', 'JB Hobbs (ENG)', 'BC Lara (ICC/WI)', 'Javed Miandad (PAK)'])]
# Out:
#                  Player       Span Matches  Inns  Not_Outs   Runs High_Score  \
# 10       GS Sobers (WI)  1954-1974      93   160        21   8032       365*
# 11       GS Sobers (WI)  1954-1974      93   160        21   8032       365*
# 14       JB Hobbs (ENG)  1908-1930      61   102         7   5410        211
# 15       JB Hobbs (ENG)  1908-1930      61   102         7   5410        211
# 26     BC Lara (ICC/WI)  1990-2006     131   232         6  11953       400*
# 27     BC Lara (ICC/WI)  1990-2006     131   232         6  11953       400*
# 28  Javed Miandad (PAK)  1976-1993     124   189        21   8832       280*
# 29  Javed Miandad (PAK)  1976-1993     124   189        21   8832       280*
#
#     Average Balls_Faced  Batting_Strike_Rate  100  50   0    4s   6s
# 10  *57.78*       4063+                53.58   26  30  12  593+  32+
# 11  *57.78*       4063+                53.58   26  30  12  593+  32+
# 14  *56.94*       5363+                46.22   15  28   4  276+    8
# ...

# %%
df = df.drop_duplicates()

# %%
df[df['Player'].isin(['GS Sobers (WI)', 'JB Hobbs (ENG)', 'BC Lara (ICC/WI)', 'Javed Miandad (PAK)'])]
# Out:
#                  Player       Span Matches  Inns  Not_Outs   Runs High_Score  \
# 10       GS Sobers (WI)  1954-1974      93   160        21   8032       365*
# 14       JB Hobbs (ENG)  1908-1930      61   102         7   5410        211
# 26     BC Lara (ICC/WI)  1990-2006     131   232         6  11953       400*
# 28  Javed Miandad (PAK)  1976-1993     124   189        21   8832       280*
#
#     Average Balls_Faced  Batting_Strike_Rate  100  50   0    4s   6s
# 10  *57.78*       4063+                53.58   26  30  12  593+  32+
# 14  *56.94*       5363+                46.22   15  28   4  276+    8
# 26  *52.88*       19753                60.51   34  48  17  1559   88
# 28  *52.57*      15164+                45.99   23  43   6  788+   48

# %%
# split span into start year and end year

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2015, 2016]
# 2     [1963, 1970]
# 3     [1930, 1954]
# 4     [1924, 1935]
#           ...
# 61    [1965, 1981]
# 62    [2002, 2014]
# 63    [1924, 1934]
# 64    [1930, 1938]
# 65    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat = '-').str[0]
# Out:
# 0     1928
# 1     2015
# 2     1963
# 3     1930
# 4     1924
#       ...
# 61    1965
# 62    2002
# 63    1924
# 64    1930
# 65    1928
# Name: Span, Length: 62, dtype: object

# %%
df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#                Player       Span Matches  Inns  Not_Outs  Runs High_Score  \
# 0    DG Bradman (AUS)  1928-1948      52    80        10  6996        334
# 1      AC Voges (AUS)  2015-2016      20    31         7  1485       269*
# 2     RG Pollock (SA)  1963-1970      23    41         4  2256        274
# 3     GA Headley (WI)  1930-1954      22    40         4  2190       270*
# 4   H Sutcliffe (ENG)  1924-1935      54    84         9  4555        194
# ..                ...        ...     ...   ...       ...   ...        ...
# 61   KD Walters (AUS)  1965-1981      74   125        14  5357        250
# 62  GC Smith (ICC/SA)  2002-2014     117   205        13  9265        277
# 63  WH Ponsford (AUS)  1924-1934      29    48         4  2122        266
# 64    SJ McCabe (AUS)  1930-1938      39    62         5  2748        232
# 65   DR Jardine (ENG)  1928-1934      22    33         6  1296        127
#
#     Average Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s  \
# ...

# %%
df = df.drop(['Span'], axis = 1)

# %%
print(df.columns)
# Out:
# Index(['Player', 'Matches', 'Inns', 'Not_Outs', 'Runs', 'High_Score',
#        'Average', 'Balls_Faced', 'Batting_Strike_Rate', '100', '50', '0', '4s',
#        '6s', 'Rookie_Year', 'Final_Year'],
#       dtype='object')

# %%
df.head()
# Out:
#               Player Matches  Inns  Not_Outs  Runs High_Score  Average  \
# 0   DG Bradman (AUS)      52    80        10  6996        334  *99.94*
# 1     AC Voges (AUS)      20    31         7  1485       269*  *61.87*
# 2    RG Pollock (SA)      23    41         4  2256        274  *60.97*
# 3    GA Headley (WI)      22    40         4  2190       270*  *60.83*
# 4  H Sutcliffe (ENG)      54    84         9  4555        194  *60.73*
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7  626+   6        1928
# 1        2667                55.68    5   4  2   186   5        2015
# 2       1707+                54.48    7  11  1  246+  11        1963
# 3        416+                56.00   10   5  2  104+   1        1930
# 4       6558+                34.59   16  23  2  202+   6        1924
#
#   Final_Year
# 0       1948
# 1       2016
# 2       1970
# 3       1954
# 4       1935

# %%
df['Player'].str.split(pat = '(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [AC Voges , AUS)]
# 2       [RG Pollock , SA)]
# 3       [GA Headley , WI)]
# 4     [H Sutcliffe , ENG)]
#               ...
# 61     [KD Walters , AUS)]
# 62    [GC Smith , ICC/SA)]
# 63    [WH Ponsford , AUS)]
# 64      [SJ McCabe , AUS)]
# 65     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1]

# %%
df['Country'].str.split(pat = ')')
# Out:
# 0        [AUS, ]
# 1        [AUS, ]
# 2         [SA, ]
# 3         [WI, ]
# 4        [ENG, ]
#          ...
# 61       [AUS, ]
# 62    [ICC/SA, ]
# 63       [AUS, ]
# 64       [AUS, ]
# 65       [ENG, ]
# Name: Country, Length: 62, dtype: object

# %%
df['Country']
# Out:
# 0        AUS)
# 1        AUS)
# 2         SA)
# 3         WI)
# 4        ENG)
#        ...
# 61       AUS)
# 62    ICC/SA)
# 63       AUS)
# 64       AUS)
# 65       ENG)
# Name: Country, Length: 62, dtype: object

# %%
df['Country'] = df['Country'].str.replace(')', '', regex=False)

# %%
df['Country']
# Out:
# 0        AUS
# 1        AUS
# 2         SA
# 3         WI
# 4        ENG
#        ...
# 61       AUS
# 62    ICC/SA
# 63       AUS
# 64       AUS
# 65       ENG
# Name: Country, Length: 62, dtype: object

# %%
df.head()
# Out:
#               Player Matches  Inns  Not_Outs  Runs High_Score  Average  \
# 0   DG Bradman (AUS)      52    80        10  6996        334  *99.94*
# 1     AC Voges (AUS)      20    31         7  1485       269*  *61.87*
# 2    RG Pollock (SA)      23    41         4  2256        274  *60.97*
# 3    GA Headley (WI)      22    40         4  2190       270*  *60.83*
# 4  H Sutcliffe (ENG)      54    84         9  4555        194  *60.73*
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7  626+   6        1928
# 1        2667                55.68    5   4  2   186   5        2015
# 2       1707+                54.48    7  11  1  246+  11        1963
# 3        416+                56.00   10   5  2  104+   1        1930
# 4       6558+                34.59   16  23  2  202+   6        1924
#
#   Final_Year Country
# 0       1948     AUS
# 1       2016     AUS
# 2       1970      SA
# 3       1954      WI
# ...

# %%
df.dtypes
# Out:
# Player                  object
# Matches                 object
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# High_Score              object
# Average                 object
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['High_Score'].str.split(pat = '*').str[0]
# Out:
# 0     334
# 1     269
# 2     274
# 3     270
# 4     194
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: High_Score, Length: 62, dtype: object

# %%
df['High_Score'] = df['High_Score'].str.split(pat ='*').str[0]

# %%
df['High_Score'] = df['High_Score'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                 object
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# High_Score               int32
# Average                 object
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df = df.astype({'Rookie_Year':'int', 'Final_Year':'int'})

# %%
df.dtypes
# Out:
# Player                  object
# Matches                 object
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# High_Score               int32
# Average                 object
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df['Matches'] = df['Matches'].str.split(pat = '*').str[0]

# %%
df = df.astype({'Matches':'int'})

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int32
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# High_Score               int32
# Average                 object
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Matches, Inns, Not_Outs, Runs, High_Score, Average, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s, Rookie_Year, Final_Year, Country]
# Index: []

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int32
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# High_Score               int32
# Average                 object
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df['4s'] = df['4s'].str.split(pat = '+').str[0]

# %%
df['4s'] = df['4s'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int32
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# High_Score               int32
# Average                 object
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int32
# 6s                      object
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df['6s'] = df['6s'].str.split(pat = '+').str[0]

# %%
df['6s'] = df['6s'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int32
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# High_Score               int32
# Average                 object
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int32
# 6s                       int32
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df['Average'] = df['Average'].str.split(pat = '*').str[0]

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int32
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# High_Score               int32
# Average                 object
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int32
# 6s                       int32
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs  Runs  High_Score Average  \
# 0    DG Bradman (AUS)       52    80        10  6996         334
# 1      AC Voges (AUS)       20    31         7  1485         269
# 2     RG Pollock (SA)       23    41         4  2256         274
# 3     GA Headley (WI)       22    40         4  2190         270
# 4   H Sutcliffe (ENG)       54    84         9  4555         194
# ..                ...      ...   ...       ...   ...         ...     ...
# 61   KD Walters (AUS)       74   125        14  5357         250
# 62  GC Smith (ICC/SA)      117   205        13  9265         277
# 63  WH Ponsford (AUS)       29    48         4  2122         266
# 64    SJ McCabe (AUS)       39    62         5  2748         232
# 65   DR Jardine (ENG)       22    33         6  1296         127
#
#     Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s  Rookie_Year  \
# 0          9800                58.60   29  13   7   626   6         1928
# ...

# %%
df['Average'] = df['Average'].str.replace('*', '', regex=False)

# %%
df.head()
# Out:
#               Player  Matches  Inns  Not_Outs  Runs  High_Score Average  \
# 0   DG Bradman (AUS)       52    80        10  6996         334   99.94
# 1     AC Voges (AUS)       20    31         7  1485         269   61.87
# 2    RG Pollock (SA)       23    41         4  2256         274   60.97
# 3    GA Headley (WI)       22    40         4  2190         270   60.83
# 4  H Sutcliffe (ENG)       54    84         9  4555         194   60.73
#
#    Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 0         9800                58.60   29  13  7  626   6         1928
# 1         2667                55.68    5   4  2  186   5         2015
# 2         1707                54.48    7  11  1  246  11         1963
# 3          416                56.00   10   5  2  104   1         1930
# 4         6558                34.59   16  23  2  202   6         1924
#
#    Final_Year Country
# 0        1948     AUS
# 1        2016     AUS
# 2        1970      SA
# ...

# %%
df['Average'] = df['Average'].astype('float')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int32
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# High_Score               int32
# Average                float64
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int32
# 6s                       int32
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
# build out career length column
# hint convert rookie/final year and subtract

# %%
df['Career_Length'] = df['Final_Year'] - df['Rookie_Year']

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs  Runs  High_Score  Average  \
# 0    DG Bradman (AUS)       52    80        10  6996         334    99.94
# 1      AC Voges (AUS)       20    31         7  1485         269    61.87
# 2     RG Pollock (SA)       23    41         4  2256         274    60.97
# 3     GA Headley (WI)       22    40         4  2190         270    60.83
# 4   H Sutcliffe (ENG)       54    84         9  4555         194    60.73
# ..                ...      ...   ...       ...   ...         ...      ...
# 61   KD Walters (AUS)       74   125        14  5357         250    48.26
# 62  GC Smith (ICC/SA)      117   205        13  9265         277    48.25
# 63  WH Ponsford (AUS)       29    48         4  2122         266    48.22
# 64    SJ McCabe (AUS)       39    62         5  2748         232    48.21
# 65   DR Jardine (ENG)       22    33         6  1296         127    48.00
#
#     Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s  Rookie_Year  \
# ...

# %% [markdown]
# # calculations with this data frame

# %%
# what is the average career length of cricketers?

# %%
df['Career_Length'].mean()
# Out:
# 13.209677419354838

# %%
# Average Batting_Strike_Rate for cricketers who played over 10 years?

# %%
df[df['Career_Length'] > 10]['Batting_Strike_Rate'].mean()
# Out:
# 47.95113636363636

# %%
# find number of players who played before 1960

# %%
df[df['Rookie_Year'] < 1960]['Player'].count()
# Out:
# 23

# %%
# Question 4 max highest score by country

# %%
df.groupby('Country')['High_Score'].max().to_frame('High_Inns_By_Country').reset_index().sort_values('High_Inns_By_Country', ascending = False)
# Out:
#     Country  High_Inns_By_Country
# 5    ICC/WI                   400
# 0       AUS                   380
# 10       SL                   374
# 11       WI                   365
# 1       ENG                   364
# 3   ICC/PAK                   329
# 2   ICC/IND                   319
# 8       PAK                   313
# 9        SA                   278
# 4    ICC/SA                   277
# 6       IND                   254
# 7        NZ                   251
# 12      ZIM                   232

# %%
# Question5 Hundreds, Fifties, ducks (0) average by country

# %%
df.groupby('Country')[['100', '50', '0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.375000   8.562500
# ENG      12.538462  21.076923   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  22.000000   6.000000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
